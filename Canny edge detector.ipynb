# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Desktop.jpg')

# %%
img1 = cv2.Canny(img, 100, 200)

# %%
plt.figure()
plt.imshow(img1)
plt.show()

# %%
#cv2.imshow("Edge_Detected",img1)
#cv2.waitKey(30)
# Out:
# -1
